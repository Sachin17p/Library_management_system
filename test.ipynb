# %%
class Book:
    def __init__(self,book_id,title,author,category,count):
        self.book_id = book_id
        self.title = title
        self.author = author
        self.category = category
        self.count = count
        self.is_borrowed = False
        
    def __str__(self):
        return f"(ID: {self.book_id}, Title: {self.title}, Author: {self.author}, Category: {self.category}, Count: {self.count})"



# Defining the class Member to handle the members attributes and return a string with all the info when called
class Member:
    def __init__(self,user_id,name,mail):
        self.name = name 
        self.user_id = user_id
        self.mail = mail 
        self.borrowed_books = []
        
    def __str__(self):
        self.borrowed_books_str = ', '.join(f"{book.book_id}:{book.title}" for book in self.borrowed_books)
        return f"(User ID: {self.user_id}, Name: {self.name}, Mail: {self.mail}, Borrowed Books: {self.borrowed_books_str})"



# Importing necessary libraries
import os                               # To handle files
from tabulate import tabulate           # To represent data
import pandas as pd                     # For representing the data as pandas Dataframe



# Defining the class Library to carry out all the necessary operations of the library
class Library:

    # The constructor method
    def __init__(self):
        self.books = []
        self.members = []
        self.load_books()
        self.load_members()
        

    # Adding a new book 
    def add_book(self, book):
        # Validate book_id format
        if not (book.book_id.startswith('b') and book.book_id[1:].isdigit()):
            print("\033[91mInvalid Book ID. Valid book ID starts with 'b' followed by a number\033[0m")
            return

        existing_book_by_id = self.find_book_by_id(book.book_id)

        if existing_book_by_id:
            if existing_book_by_id.title != book.title:
                print("\033[91mError! That book ID had a different book. Use another book ID\033[0m")
                return
            elif (existing_book_by_id.author == book.author and
                  existing_book_by_id.category == book.category):
                existing_book_by_id.count += 1
                print("\033[92mBook count incremented successfully!\033[0m")
            else:
                print("\033[91mError! That book ID had a different book. Use another book ID\033[0m")
                return
        else:
            self.books.append(book)
            print("\033[92mBook added successfully!\033[0m")
        self.save_books()

    # Finding a book by its title
    def find_book_by_title(self, title):
        for book in self.books:
            if book.title == title:
                return book
        return None


    # Removing all the copies of a particular book
    def remove_book(self,book):
        self.books = [book for book in self.books if book.book_id != book_id]
        self.save_book()

        
    # Updating the books.txt file after every operation whenever Library class is instantiated
    def save_books(self):
        with open('books.txt', 'w') as f:
            for book in self.books:
                f.write(f"{book.book_id},{book.title},{book.author},{book.category},{book.is_borrowed},{book.count}\n")



    # Updating the members.txt file after every operation whenever Library class is instantiated
    def save_members(self):
        with open('members.txt', 'w') as f:
            for member in self.members:
                borrowed_books_str = ','.join(book.book_id for book in member.borrowed_books)
                f.write(f"{member.user_id},{member.name},{member.mail},{borrowed_books_str}\n")


    # Adding a new member after checking if it already exists
    def add_member(self, member):
        # Validate user_id format
        if not (member.user_id.startswith('m') and member.user_id[1:].isdigit()):
            print("\033[91mInvalid User ID. Valid user ID starts with 'm' followed by a number\033[0m")
            return

        # Check if the user_id already exists
        existing_member_by_id = self.find_member_by_id(member.user_id)
        if existing_member_by_id:
            print("\033[91mError! That user ID already exists. Use another user ID\033[0m")
            return

        # Check if the mail ID already exists
        for existing_member in self.members:
            if existing_member.mail == member.mail:
                print("\033[91mEnter a different mail ID, the entered mail ID already exists.\033[0m")
                return

        # Add the new member if no conflicts are found
        self.members.append(member)
        self.save_members()
        print("\033[92mMember added successfully!\033[0m")

    # Finding a member by its name
    def find_member_by_name(self, name):
        for member in self.members:
            if member.name == name:
                return member
        return None


    # Removing a member 
    def remove_member(self, user_id):
        self.members = [member for member in self.members if member.user_id != user_id]
        self.save_members()


    # Borrowing a book by checking if that book and at least one copy of the same is available
    def borrow_book(self, user_id, book_id):
        member = self.find_member_by_id(user_id)
        if not member:
            print("\033[91mMember not found in database! Add your details to the database!\033[0m")
        book = self.find_book_by_id(book_id)
        if member and book:
            if book.count > 0:
                book.count -= 1
                member.borrowed_books.append(book)
                self.save_books()
                self.save_members()
                return True
            else:
                print("\033[91mNo copies available.\033[0m")
        return False



    # Returning a borrowed book 
    def return_book(self, user_id, book_id):
        member = self.find_member_by_id(user_id)
        book = self.find_book_by_id(book_id)
        if member and book:
            if book in member.borrowed_books:
                book.count += 1
                member.borrowed_books = [b for b in member.borrowed_books if b.book_id != book_id]
                self.save_books()
                self.save_members()
                return True
            else:
                # Adding the book to the library if it was not previously in the library
                book_to_return = Book(book_id, "Unknown Title", "Unknown Author", "Unknown Category", 1)
                self.add_book(book_to_return)
                return True
        return False


    # Listing all the available books and their info
    def list_books(self):
        # Create a DataFrame
        df = pd.DataFrame([{
            'Book ID': book.book_id,
            'Title': book.title,
            'Author': book.author,
            'Category': book.category,
            'Count': book.count
        } for book in self.books])

        return df


    # Listing all the current member of the library with all the info
    def list_members(self):
    # Create a list of dictionaries, each representing a member
        members_data = [{
            'User ID': member.user_id,
            'Name': member.name,
            'Mail': member.mail,
            'Borrowed Books': f"[{', '.join(f'{book.book_id}: {book.title}' for book in member.borrowed_books)}]",
            'Borrowed Book Count': len(member.borrowed_books)
        } for member in self.members]

        return pd.DataFrame(members_data)


    # Finding a book by its book_id 
    def find_book_by_id(self, book_id):
        for book in self.books:
            if book.book_id == book_id:
                return book
        return None


    # Finding a member by its member_id
    def find_member_by_id(self, user_id):
        for member in self.members:
            if member.user_id == user_id:
                return member
        return None


    # Searching through the books by its book_id
    def search_books_by_book_id(self, book_id):
        return [book for book in self.books if book_id.lower() in book.book_id.lower()]


    # Searching through the books by title
    def search_books_by_title(self, title):
        return [book for book in self.books if title.lower() in book.title.lower()]

    # Searching through the books by author name
    def search_books_by_author(self, author):
        return [book for book in self.books if author.lower() in book.author.lower()]


    # Searching through the books by their category
    def search_books_by_category(self, category):
        return [book for book in self.books if category.lower() in book.category.lower()]


    # Loading books into the books.txt file 
    def load_books(self):
        if os.path.exists('books.txt'):
            with open('books.txt', 'r') as f:
                for line in f:
                    parts = line.strip().split(',')
                    book_id = parts[0]
                    title = parts[1]
                    author = parts[2]
                    category = parts[3]
                    count = int(parts[5])
                    book = Book(book_id, title, author, category, count)
                    self.books.append(book)


    # Loading the members and updated info into members.txt file
    def load_members(self):
        if os.path.exists('members.txt'):
            with open('members.txt', 'r') as f:
                for line in f:
                    parts = line.strip().split(',')
                    user_id = parts[0]           # 1st argument of members.txt
                    name = parts[1]              # 2nd argument of members.txt
                    mail = parts[2]              # 3rd argument of members.txt
                    borrowed_books = parts[3:]   # 4th and later arguments of members.txt

                    member = Member(user_id, name, mail)
                    for book_id in borrowed_books:
                        if book_id:
                            book = self.find_book_by_id(book_id)
                            if book:
                                member.borrowed_books.append(book)
                    self.members.append(member)




# Ewxecuting the program with all the options
if __name__ == "__main__":
    library = Library()

    while True:
        print("\nOpen Source Library Management System")
        print("1. Add a New Book")
        print("2. Remove a Book")
        print("3. Add a New Member")
        print("4. Remove a Member")
        print("5. Borrow a Book")
        print("6. Return a Book")
        print("7. List all Books")
        print("8. List all Members")
        print("9. Search Books by Title")
        print("10. Search Books by Author")
        print("11. Search Books by Category")
        print("12. Search Books by Book ID")
        print("13. Exit")

        choice = input("Choose an option: ")

        if choice == '1':
            book_id = input("Enter book ID: ")
            title = input("Enter book title: ")
            author = input("Enter book author: ")
            category = input("Enter book category: ")
            library.add_book(Book(book_id, title, author, category, 1))
            
        
        elif choice == '2':
            book_id = input("Enter book ID to remove: ")
            library.remove_book(book_id)
            print("\033[92mBook removed successfully.\033[0m")
        
        elif choice == '3':
            user_id = input("Enter member ID: ")
            name = input("Enter member name: ")
            mail = input("Enter member email: ")
            library.add_member(Member(user_id, name, mail))
        
        elif choice == '4':
            user_id = input("Enter member ID to remove: ")
            library.remove_member(user_id)
            print("\033[92mMember removed successfully.\033[0m")
        
        elif choice == '5':
            user_id = input("Enter member ID: ")
            book_id = input("Enter book ID to borrow: ")
            if library.borrow_book(user_id, book_id):
                print("\033[92mBook borrowed successfully.\033[0m")
            else:
                print("\033[91mBorrowing failed.\033[0m")
        
        elif choice == '6':
            user_id = input("Enter member ID: ")
            book_id = input("Enter book ID to return: ")
            if library.return_book(user_id, book_id):
                print("\033[92mBook returned successfully.\033[0m")
            else:
                print("\033[91mReturning failed.\033[0m")
        

        elif choice == '7':
            print("Books in Library:")
            df_books = library.list_books()
            print(tabulate(df_books, headers='keys', tablefmt='fancy_grid'))



        elif choice == '8':
            print("Members in Library:")
            df_members = library.list_members()
            print(tabulate(df_members, headers='keys', tablefmt='fancy_grid'))



        elif choice == '9':
            title = input("Enter book title to search: ")
            results = library.search_books_by_title(title)
            print("Search results:")
            for book in results:
                print(book)
        
        elif choice == '10':
            author = input("Enter book author to search: ")
            results = library.search_books_by_author(author)
            print("Search results:")
            for book in results:
                print(book)
        
        elif choice == '11':
            category = input("Enter book category: ")
            results = library.search_books_by_category(category)
            print("Search results: ")
            for book in results:
                print(book)
            
        elif choice == '12':
            book_id = input("Enter Book ID: ")
            results = library.search_books_by_book_id(book_id)
            for book in results:
                print(book)
                
        elif choice == '13':
            print("Exiting the system.")
            break
        
        else:
            print("Invalid choice. Please try again.")
# Out:
# Open Source Library Management System
# 1. Add a New Book
# 2. Remove a Book
# 3. Add a New Member
# 4. Remove a Member
# 5. Borrow a Book
# 6. Return a Book
# 7. List all Books
# 8. List all Members
# 9. Search Books by Title
# 10. Search Books by Author
# 11. Search Books by Category
# 12. Search Books by Book ID
# 13. Exit
# Choose an option: 7
# Books in Library:
# ╒═════╤═══════════╤═══════════════════════════════════════╤═════════════════════════════╤════════════════════╤═════════╕
# │     │ Book ID   │ Title                                 │ Author                      │ Category           │   Count │
# ╞═════╪═══════════╪═══════════════════════════════════════╪═════════════════════════════╪════════════════════╪═════════╡
# │   0 │ b201      │ 2 states                              │ Chetan Bhagat               │ Novel              │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   1 │ b2        │ To Kill a Mockingbird                 │ Harper Lee                  │ Classic            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   2 │ b3        │ 1984                                  │ George Orwell               │ Dystopian          │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   3 │ b4        │ Pride and Prejudice                   │ Jane Austen                 │ Classic            │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   4 │ b5        │ The Great Gatsby                      │ F. Scott Fitzgerald         │ Classic            │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   5 │ b6        │ Moby-Dick                             │ Herman Melville             │ Adventure          │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   6 │ b7        │ War and Peace                         │ Leo Tolstoy                 │ Historical Fiction │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   7 │ b8        │ Crime and Punishment                  │ Fyodor Dostoevsky           │ Classic            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   8 │ b9        │ The Catcher in the Rye                │ J.D. Salinger               │ Classic            │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │   9 │ b10       │ The Lord of the Rings                 │ J.R.R. Tolkien              │ Fantasy            │      18 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  10 │ b11       │ The Hobbit                            │ J.R.R. Tolkien              │ Fantasy            │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  11 │ b12       │ Harry Potter and the Sorcerer's Stone │ J.K. Rowling                │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  12 │ b13       │ Fahrenheit 451                        │ Ray Bradbury                │ Dystopian          │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  13 │ b14       │ Jane Eyre                             │ Charlotte Bronte            │ Classic            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  14 │ b15       │ Wuthering Heights                     │ Emily Bronte                │ Classic            │       6 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  15 │ b16       │ Brave New World                       │ Aldous Huxley               │ Dystopian          │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  16 │ b17       │ The Lion the Witch and the Wardrobe   │ C.S. Lewis                  │ Fantasy            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  17 │ b18       │ Animal Farm                           │ George Orwell               │ Dystopian          │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  18 │ b19       │ The Chronicles of Narnia              │ C.S. Lewis                  │ Fantasy            │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  19 │ b20       │ Little Women                          │ Louisa May Alcott           │ Classic            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  20 │ b21       │ The Alchemist                         │ Paulo Coelho                │ Fiction            │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  21 │ b22       │ The Grapes of Wrath                   │ John Steinbeck              │ Classic            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  22 │ b23       │ Slaughterhouse-Five                   │ Kurt Vonnegut               │ Science Fiction    │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  23 │ b24       │ Catch-22                              │ Joseph Heller               │ Satire             │       3 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  24 │ b25       │ The Hitchhiker's Guide to the Galaxy  │ Douglas Adams               │ Science Fiction    │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  25 │ b26       │ The Odyssey                           │ Homer                       │ Classic            │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  26 │ b27       │ The Iliad                             │ Homer                       │ Classic            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  27 │ b28       │ The Count of Monte Cristo             │ Alexandre Dumas             │ Adventure          │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  28 │ b29       │ Dracula                               │ Bram Stoker                 │ Horror             │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  29 │ b30       │ Frankenstein                          │ Mary Shelley                │ Horror             │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  30 │ b31       │ Don Quixote                           │ Miguel de Cervantes         │ Classic            │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  31 │ b32       │ A Tale of Two Cities                  │ Charles Dickens             │ Classic            │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  32 │ b33       │ Great Expectations                    │ Charles Dickens             │ Classic            │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  33 │ b34       │ Les Misérables                        │ Victor Hugo                 │ Classic            │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  34 │ b35       │ Gone with the Wind                    │ Margaret Mitchell           │ Historical Fiction │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  35 │ b36       │ The Picture of Dorian Gray            │ Oscar Wilde                 │ Classic            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  36 │ b37       │ The Brothers Karamazov                │ Fyodor Dostoevsky           │ Classic            │       2 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  37 │ b38       │ Madame Bovary                         │ Gustave Flaubert            │ Classic            │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  38 │ b39       │ The Old Man and the Sea               │ Ernest Hemingway            │ Classic            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  39 │ b40       │ The Sun Also Rises                    │ Ernest Hemingway            │ Classic            │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  40 │ b41       │ A Farewell to Arms                    │ Ernest Hemingway            │ Classic            │      16 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  41 │ b42       │ The Catcher in the Rye                │ J.D. Salinger               │ Classic            │       3 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  42 │ b43       │ On the Road                           │ Jack Kerouac                │ Classic            │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  43 │ b44       │ The Road                              │ Cormac McCarthy             │ Dystopian          │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  44 │ b45       │ Blood Meridian                        │ Cormac McCarthy             │ Western            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  45 │ b46       │ The Stand                             │ Stephen King                │ Horror             │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  46 │ b47       │ It                                    │ Stephen King                │ Horror             │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  47 │ b48       │ The Shining                           │ Stephen King                │ Horror             │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  48 │ b49       │ The Dark Tower                        │ Stephen King                │ Fantasy            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  49 │ b50       │ American Gods                         │ Neil Gaiman                 │ Fantasy            │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  50 │ b51       │ Good Omens                            │ Neil Gaiman                 │ Fantasy            │      16 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  51 │ b52       │ Neverwhere                            │ Neil Gaiman                 │ Fantasy            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  52 │ b53       │ Coraline                              │ Neil Gaiman                 │ Fantasy            │       2 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  53 │ b54       │ The Handmaid's Tale                   │ Margaret Atwood             │ Dystopian          │      16 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  54 │ b55       │ Oryx and Crake                        │ Margaret Atwood             │ Dystopian          │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  55 │ b56       │ The Blind Assassin                    │ Margaret Atwood             │ Historical Fiction │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  56 │ b57       │ The Testaments                        │ Margaret Atwood             │ Dystopian          │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  57 │ b58       │ Dune                                  │ Frank Herbert               │ Science Fiction    │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  58 │ b59       │ Foundation                            │ Isaac Asimov                │ Science Fiction    │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  59 │ b60       │ Neuromancer                           │ William Gibson              │ Science Fiction    │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  60 │ b61       │ Snow Crash                            │ Neal Stephenson             │ Science Fiction    │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  61 │ b62       │ Hyperion                              │ Dan Simmons                 │ Science Fiction    │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  62 │ b63       │ The Left Hand of Darkness             │ Ursula K. Le Guin           │ Science Fiction    │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  63 │ b64       │ The Dispossessed                      │ Ursula K. Le Guin           │ Science Fiction    │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  64 │ b65       │ A Wizard of Earthsea                  │ Ursula K. Le Guin           │ Fantasy            │      16 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  65 │ b66       │ The Name of the Wind                  │ Patrick Rothfuss            │ Fantasy            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  66 │ b67       │ The Wise Man's Fear                   │ Patrick Rothfuss            │ Fantasy            │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  67 │ b68       │ Mistborn: The Final Empire            │ Brandon Sanderson           │ Fantasy            │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  68 │ b69       │ The Way of Kings                      │ Brandon Sanderson           │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  69 │ b70       │ Elantris                              │ Brandon Sanderson           │ Fantasy            │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  70 │ b71       │ The Final Empire                      │ Brandon Sanderson           │ Fantasy            │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  71 │ b72       │ The Hero of Ages                      │ Brandon Sanderson           │ Fantasy            │       3 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  72 │ b73       │ The Well of Ascension                 │ Brandon Sanderson           │ Fantasy            │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  73 │ b74       │ The Rithmatist                        │ Brandon Sanderson           │ Fantasy            │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  74 │ b75       │ Steelheart                            │ Brandon Sanderson           │ Fantasy            │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  75 │ b76       │ Firefight                             │ Brandon Sanderson           │ Fantasy            │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  76 │ b77       │ Calamity                              │ Brandon Sanderson           │ Fantasy            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  77 │ b78       │ The Alloy of Law                      │ Brandon Sanderson           │ Fantasy            │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  78 │ b79       │ Shadows of Self                       │ Brandon Sanderson           │ Fantasy            │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  79 │ b80       │ Bands of Mourning                     │ Brandon Sanderson           │ Fantasy            │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  80 │ b81       │ Warbreaker                            │ Brandon Sanderson           │ Fantasy            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  81 │ b82       │ The Way of Kings                      │ Brandon Sanderson           │ Fantasy            │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  82 │ b83       │ Words of Radiance                     │ Brandon Sanderson           │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  83 │ b84       │ Oathbringer                           │ Brandon Sanderson           │ Fantasy            │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  84 │ b85       │ Rhythm of War                         │ Brandon Sanderson           │ Fantasy            │       6 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  85 │ b86       │ The Gunslinger                        │ Stephen King                │ Fantasy            │       2 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  86 │ b87       │ The Drawing of the Three              │ Stephen King                │ Fantasy            │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  87 │ b88       │ The Waste Lands                       │ Stephen King                │ Fantasy            │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  88 │ b89       │ Wolves of the Calla                   │ Stephen King                │ Fantasy            │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  89 │ b90       │ Song of Susannah                      │ Stephen King                │ Fantasy            │       6 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  90 │ b91       │ The Dark Tower                        │ Stephen King                │ Fantasy            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  91 │ b92       │ Wizard and Glass                      │ Stephen King                │ Fantasy            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  92 │ b93       │ The Wind Through the Keyhole          │ Stephen King                │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  93 │ b94       │ The Gunslinger                        │ Stephen King                │ Fantasy            │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  94 │ b95       │ The Drawing of the Three              │ Stephen King                │ Fantasy            │       6 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  95 │ b96       │ The Waste Lands                       │ Stephen King                │ Fantasy            │       3 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  96 │ b97       │ Wolves of the Calla                   │ Stephen King                │ Fantasy            │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  97 │ b98       │ Song of Susannah                      │ Stephen King                │ Fantasy            │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  98 │ b99       │ The Dark Tower                        │ Stephen King                │ Fantasy            │       2 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │  99 │ b100      │ Wizard and Glass                      │ Stephen King                │ Fantasy            │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 100 │ b101      │ The Wind Through the Keyhole          │ Stephen King                │ Fantasy            │       2 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 101 │ b102      │ Ender's Game                          │ Orson Scott Card            │ Science Fiction    │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 102 │ b103      │ Speaker for the Dead                  │ Orson Scott Card            │ Science Fiction    │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 103 │ b104      │ Xenocide                              │ Orson Scott Card            │ Science Fiction    │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 104 │ b105      │ Children of the Mind                  │ Orson Scott Card            │ Science Fiction    │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 105 │ b106      │ Ender's Shadow                        │ Orson Scott Card            │ Science Fiction    │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 106 │ b107      │ Shadow of the Hegemon                 │ Orson Scott Card            │ Science Fiction    │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 107 │ b108      │ Shadow Puppets                        │ Orson Scott Card            │ Science Fiction    │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 108 │ b109      │ Shadow of the Giant                   │ Orson Scott Card            │ Science Fiction    │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 109 │ b110      │ Shadows in Flight                     │ Orson Scott Card            │ Science Fiction    │      16 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 110 │ b111      │ The Hunger Games                      │ Suzanne Collins             │ Dystopian          │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 111 │ b112      │ Catching Fire                         │ Suzanne Collins             │ Dystopian          │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 112 │ b113      │ Mockingjay                            │ Suzanne Collins             │ Dystopian          │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 113 │ b114      │ Divergent                             │ Veronica Roth               │ Dystopian          │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 114 │ b115      │ Insurgent                             │ Veronica Roth               │ Dystopian          │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 115 │ b116      │ Allegiant                             │ Veronica Roth               │ Dystopian          │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 116 │ b117      │ Fable                                 │ Adrienne Young              │ Fantasy            │       6 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 117 │ b118      │ Namesake                              │ Adrienne Young              │ Fantasy            │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 118 │ b119      │ Sky in the Deep                       │ Adrienne Young              │ Fantasy            │       6 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 119 │ b120      │ The Girl the Sea Gave Back            │ Adrienne Young              │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 120 │ b121      │ Fable                                 │ Adrienne Young              │ Fantasy            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 121 │ b122      │ Namesake                              │ Adrienne Young              │ Fantasy            │       3 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 122 │ b123      │ Sky in the Deep                       │ Adrienne Young              │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 123 │ b124      │ The Girl the Sea Gave Back            │ Adrienne Young              │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 124 │ b125      │ A Court of Thorns and Roses           │ Sarah J. Maas               │ Fantasy            │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 125 │ b126      │ A Court of Mist and Fury              │ Sarah J. Maas               │ Fantasy            │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 126 │ b127      │ A Court of Wings and Ruin             │ Sarah J. Maas               │ Fantasy            │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 127 │ b128      │ A Court of Frost and Starlight        │ Sarah J. Maas               │ Fantasy            │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 128 │ b129      │ A Court of Silver Flames              │ Sarah J. Maas               │ Fantasy            │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 129 │ b130      │ Throne of Glass                       │ Sarah J. Maas               │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 130 │ b131      │ Crown of Midnight                     │ Sarah J. Maas               │ Fantasy            │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 131 │ b132      │ Heir of Fire                          │ Sarah J. Maas               │ Fantasy            │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 132 │ b133      │ Queen of Shadows                      │ Sarah J. Maas               │ Fantasy            │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 133 │ b134      │ Empire of Storms                      │ Sarah J. Maas               │ Fantasy            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 134 │ b135      │ Tower of Dawn                         │ Sarah J. Maas               │ Fantasy            │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 135 │ b136      │ Kingdom of Ash                        │ Sarah J. Maas               │ Fantasy            │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 136 │ b137      │ The Assassin's Blade                  │ Sarah J. Maas               │ Fantasy            │      18 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 137 │ b138      │ House of Earth and Blood              │ Sarah J. Maas               │ Fantasy            │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 138 │ b139      │ House of Sky and Breath               │ Sarah J. Maas               │ Fantasy            │       2 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 139 │ b140      │ A Song of Ice and Fire                │ George R.R. Martin          │ Fantasy            │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 140 │ b141      │ A Game of Thrones                     │ George R.R. Martin          │ Fantasy            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 141 │ b142      │ A Clash of Kings                      │ George R.R. Martin          │ Fantasy            │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 142 │ b143      │ A Storm of Swords                     │ George R.R. Martin          │ Fantasy            │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 143 │ b144      │ A Feast for Crows                     │ George R.R. Martin          │ Fantasy            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 144 │ b145      │ A Dance with Dragons                  │ George R.R. Martin          │ Fantasy            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 145 │ b146      │ The Winds of Winter                   │ George R.R. Martin          │ Fantasy            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 146 │ b147      │ A Dream of Spring                     │ George R.R. Martin          │ Fantasy            │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 147 │ b148      │ The World of Ice & Fire               │ George R.R. Martin          │ Fantasy            │      16 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 148 │ b149      │ Fire & Blood                          │ George R.R. Martin          │ Fantasy            │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 149 │ b150      │ Roadside Picnic                       │ Arkady and Boris Strugatsky │ Science Fiction    │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 150 │ b151      │ Metro 2033                            │ Dmitry Glukhovsky           │ Dystopian          │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 151 │ b152      │ Metro 2034                            │ Dmitry Glukhovsky           │ Dystopian          │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 152 │ b153      │ Metro 2035                            │ Dmitry Glukhovsky           │ Dystopian          │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 153 │ b154      │ The Road                              │ Cormac McCarthy             │ Dystopian          │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 154 │ b155      │ Station Eleven                        │ Emily St. John Mandel       │ Dystopian          │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 155 │ b156      │ The Book of M                         │ Peng Shepherd               │ Dystopian          │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 156 │ b157      │ The Water Knife                       │ Paolo Bacigalupi            │ Dystopian          │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 157 │ b158      │ The Drowned Cities                    │ Paolo Bacigalupi            │ Dystopian          │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 158 │ b159      │ Ship Breaker                          │ Paolo Bacigalupi            │ Dystopian          │       3 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 159 │ b160      │ The Windup Girl                       │ Paolo Bacigalupi            │ Dystopian          │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 160 │ b161      │ The Children of Men                   │ P.D. James                  │ Dystopian          │       5 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 161 │ b162      │ Blindness                             │ José Saramago               │ Dystopian          │       6 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 162 │ b163      │ The Giver                             │ Lois Lowry                  │ Dystopian          │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 163 │ b164      │ Gathering Blue                        │ Lois Lowry                  │ Dystopian          │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 164 │ b165      │ Messenger                             │ Lois Lowry                  │ Dystopian          │       4 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 165 │ b166      │ Son                                   │ Lois Lowry                  │ Dystopian          │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 166 │ b167      │ The Maze Runner                       │ James Dashner               │ Dystopian          │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 167 │ b168      │ The Scorch Trials                     │ James Dashner               │ Dystopian          │      16 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 168 │ b169      │ The Death Cure                        │ James Dashner               │ Dystopian          │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 169 │ b170      │ The Kill Order                        │ James Dashner               │ Dystopian          │       3 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 170 │ b171      │ The Fever Code                        │ James Dashner               │ Dystopian          │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 171 │ b172      │ The 5th Wave                          │ Rick Yancey                 │ Dystopian          │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 172 │ b173      │ The Infinite Sea                      │ Rick Yancey                 │ Dystopian          │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 173 │ b174      │ The Last Star                         │ Rick Yancey                 │ Dystopian          │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 174 │ b175      │ The Martian                           │ Andy Weir                   │ Science Fiction    │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 175 │ b176      │ Artemis                               │ Andy Weir                   │ Science Fiction    │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 176 │ b177      │ Project Hail Mary                     │ Andy Weir                   │ Science Fiction    │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 177 │ b178      │ Ready Player One                      │ Ernest Cline                │ Science Fiction    │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 178 │ b179      │ Ready Player Two                      │ Ernest Cline                │ Science Fiction    │      15 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 179 │ b180      │ Armada                                │ Ernest Cline                │ Science Fiction    │      10 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 180 │ b181      │ Altered Carbon                        │ Richard K. Morgan           │ Science Fiction    │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 181 │ b182      │ Broken Angels                         │ Richard K. Morgan           │ Science Fiction    │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 182 │ b183      │ Woken Furies                          │ Richard K. Morgan           │ Science Fiction    │      14 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 183 │ b184      │ Do Androids Dream of Electric Sheep?  │ Philip K. Dick              │ Science Fiction    │       1 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 184 │ b185      │ The Man in the High Castle            │ Philip K. Dick              │ Science Fiction    │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 185 │ b186      │ Ubik                                  │ Philip K. Dick              │ Science Fiction    │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 186 │ b187      │ A Scanner Darkly                      │ Philip K. Dick              │ Science Fiction    │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 187 │ b188      │ Flow My Tears the Policeman Said      │ Philip K. Dick              │ Science Fiction    │      13 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 188 │ b189      │ The Three-Body Problem                │ Liu Cixin                   │ Science Fiction    │       9 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 189 │ b190      │ The Dark Forest                       │ Liu Cixin                   │ Science Fiction    │       7 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 190 │ b191      │ Death's End                           │ Liu Cixin                   │ Science Fiction    │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 191 │ b192      │ The Wandering Earth                   │ Liu Cixin                   │ Science Fiction    │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 192 │ b193      │ Ball Lightning                        │ Liu Cixin                   │ Science Fiction    │       2 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 193 │ b194      │ The Invisible Library                 │ Genevieve Cogman            │ Fantasy            │      20 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 194 │ b195      │ The Masked City                       │ Genevieve Cogman            │ Fantasy            │      11 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 195 │ b196      │ The Burning Page                      │ Genevieve Cogman            │ Fantasy            │      17 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 196 │ b197      │ The Lost Plot                         │ Genevieve Cogman            │ Fantasy            │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 197 │ b198      │ The Mortal Word                       │ Genevieve Cogman            │ Fantasy            │       8 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 198 │ b199      │ The Secret Chapter                    │ Genevieve Cogman            │ Fantasy            │      12 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 199 │ b200      │ The Dark Archive                      │ Genevieve Cogman            │ Fantasy            │      19 │
# ├─────┼───────────┼───────────────────────────────────────┼─────────────────────────────┼────────────────────┼─────────┤
# │ 200 │ b1        │ A song of Ice and Fire                │ R.R. Martin                 │ Novel              │       2 │
# ╘═════╧═══════════╧═══════════════════════════════════════╧═════════════════════════════╧════════════════════╧═════════╛
#
# Open Source Library Management System
# 1. Add a New Book
# 2. Remove a Book
# 3. Add a New Member
# 4. Remove a Member
# 5. Borrow a Book
# 6. Return a Book
# 7. List all Books
# 8. List all Members
# 9. Search Books by Title
# 10. Search Books by Author
# 11. Search Books by Category
# 12. Search Books by Book ID
# 13. Exit
# Choose an option: 8
# Members in Library:
# ╒════╤═══════════╤═════════════╤════════════════════╤══════════════════╤═══════════════════════╕
# │    │ User ID   │ Name        │ Mail               │ Borrowed Books   │   Borrowed Book Count │
# ╞════╪═══════════╪═════════════╪════════════════════╪══════════════════╪═══════════════════════╡
# │  0 │ m1        │ Sachin      │ sac@gmail.com      │ []               │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼──────────────────┼───────────────────────┤
# │  1 │ m2        │ Aryan Patel │ ap@gmail.com       │ []               │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼──────────────────┼───────────────────────┤
# │  2 │ m3        │ Kamlesh     │ kamlesh@gmail.com  │ []               │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼──────────────────┼───────────────────────┤
# │  3 │ m4        │ Bharati     │ bh_patel@gmail.com │ []               │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼──────────────────┼───────────────────────┤
# │  4 │ m5        │ Amit        │ amit@gmail.com     │ []               │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼──────────────────┼───────────────────────┤
# │  5 │ m6        │ Ashok       │ ashok@gmail.com    │ []               │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼──────────────────┼───────────────────────┤
# │  6 │ m7        │ Daljin      │ daljin@gmail.com   │ []               │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼──────────────────┼───────────────────────┤
# │  7 │ m8        │ Lasya       │ lasya@gmail.com    │ []               │                     0 │
# ╘════╧═══════════╧═════════════╧════════════════════╧══════════════════╧═══════════════════════╛
#
# Open Source Library Management System
# 1. Add a New Book
# 2. Remove a Book
# 3. Add a New Member
# 4. Remove a Member
# 5. Borrow a Book
# 6. Return a Book
# 7. List all Books
# 8. List all Members
# 9. Search Books by Title
# 10. Search Books by Author
# 11. Search Books by Category
# 12. Search Books by Book ID
# 13. Exit
# Choose an option: 5
# Enter member ID: m1
# Enter book ID to borrow: b197
# Book borrowed successfully.
#
# Open Source Library Management System
# 1. Add a New Book
# 2. Remove a Book
# 3. Add a New Member
# 4. Remove a Member
# 5. Borrow a Book
# 6. Return a Book
# 7. List all Books
# 8. List all Members
# 9. Search Books by Title
# 10. Search Books by Author
# 11. Search Books by Category
# 12. Search Books by Book ID
# 13. Exit
# Choose an option: 8
# Members in Library:
# ╒════╤═══════════╤═════════════╤════════════════════╤═══════════════════════╤═══════════════════════╕
# │    │ User ID   │ Name        │ Mail               │ Borrowed Books        │   Borrowed Book Count │
# ╞════╪═══════════╪═════════════╪════════════════════╪═══════════════════════╪═══════════════════════╡
# │  0 │ m1        │ Sachin      │ sac@gmail.com      │ [b197: The Lost Plot] │                     1 │
# ├────┼───────────┼─────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │  1 │ m2        │ Aryan Patel │ ap@gmail.com       │ []                    │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │  2 │ m3        │ Kamlesh     │ kamlesh@gmail.com  │ []                    │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │  3 │ m4        │ Bharati     │ bh_patel@gmail.com │ []                    │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │  4 │ m5        │ Amit        │ amit@gmail.com     │ []                    │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │  5 │ m6        │ Ashok       │ ashok@gmail.com    │ []                    │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │  6 │ m7        │ Daljin      │ daljin@gmail.com   │ []                    │                     0 │
# ├────┼───────────┼─────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │  7 │ m8        │ Lasya       │ lasya@gmail.com    │ []                    │                     0 │
# ╘════╧═══════════╧═════════════╧════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Open Source Library Management System
# 1. Add a New Book
# 2. Remove a Book
# 3. Add a New Member
# 4. Remove a Member
# 5. Borrow a Book
# 6. Return a Book
# 7. List all Books
# 8. List all Members
# 9. Search Books by Title
# 10. Search Books by Author
# 11. Search Books by Category
# 12. Search Books by Book ID
# 13. Exit
# Choose an option: 13
# Exiting the system.
